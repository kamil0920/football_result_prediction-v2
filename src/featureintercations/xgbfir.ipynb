# %%
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.metrics import precision_score

import xgboost as xgb

from src.helper import get_split_data

# %%
X_trn, y_trn, X_val, y_val, X_tst, y_tst = get_split_data.split_data_for_training(6)

# %%
params = {'colsample_bytree': 0.8829682348067726,
          'gamma': 2.153140019195803,
          'learning_rate': 0.2839181641252695,
          'max_depth': 10,
          'n_estimators': 750,
          'reg_alpha': 0.05456053939633371,
          'reg_lambda': 0.014211434927705319,
          'subsample': 0.8413541436147373
          }

xg = xgb.XGBClassifier(**params, random_state=42)
xg.fit(X_trn, y_trn, eval_set=[(X_trn, y_trn), (X_val, y_val)], verbose=False)
y_pred = xg.predict(X_tst)

precision_score(y_tst, y_pred, average='binary').round(3)
# Out:
# np.float64(0.333)

# %%
import xgbfir

xgbfir.saveXgbFI(xg, feature_names=X_trn.columns, OutputXlsxFile='fir.xlsx')

# %%
X_trn.columns
# Out:
# Index(['points_home', 'points_away', 'home_last_team_goal',
#        'home_last_team_shoton', 'home_last_team_possession',
#        'away_last_team_goal', 'away_last_team_shoton',
#        'away_last_team_possession', 'team_strength_home', 'team_strength_away',
#        'strength_difference', 'team_aggression_home', 'team_aggression_away',
#        'aggression_difference', 'team_acceleration_home',
#        'team_acceleration_away', 'acceleration_difference',
#        'points_difference', 'goal_conversion_rate_home',
#        'goal_conversion_rate_away', 'rolling_avg_goals_home',
#        'rolling_avg_goals_away', 'season_2009/2010', 'season_2010/2011',
#        'season_2011/2012', 'season_2012/2013', 'season_2013/2014',
#        'season_2014/2015', 'season_2015/2016'],
#       dtype='object')

# %%
fir = pd.read_excel('fir.xlsx')
fir.sort_values(by='Average Rank').head().round(1)
# Out:
#                  Interaction   Gain  FScore  wFScore  Average wFScore  \
# 0          points_difference  541.6      52     15.9              0.3
# 1     team_acceleration_home  341.9      78      8.9              0.1
# 4     team_acceleration_away  273.3      63      8.3              0.1
# 5  away_last_team_possession  232.8      54      8.5              0.2
# 2       team_aggression_away  280.6      67      7.8              0.1
#
#    Average Gain  Expected Gain  Gain Rank  FScore Rank  wFScore Rank  \
# 0          10.4          375.2          1            6             1
# 1           4.4           48.2          2            1             2
# 4           4.3           34.8          5            4             4
# 5           4.3           32.2          6            5             3
# 2           4.2           27.1          3            2             5
#
#    Avg wFScore Rank  Avg Gain Rank  Expected Gain Rank  Average Rank  \
# 0                 2              1                   1           2.0
# 1                14              8                   2           4.8
# 4                 9              9                   3           5.7
# 5                 6             10                   5           5.8
# 2                13             13                   6           7.0
#
#    Average Tree Index  Average Tree Depth
# 0                 8.4                 4.3
# 1                 6.5                 5.8
# 4                 6.6                 5.9
# 5                 7.8                 5.2
# 2                11.1                 5.5

# %%
pd.read_excel('fir.xlsx', sheet_name='Interaction Depth 1').iloc[:20].sort_values(by='Average Rank').head(10).round(1)
# Out:
#                                          Interaction   Gain  FScore  wFScore  \
# 1           points_difference|team_acceleration_home  290.0      10      2.8
# 0                points_difference|points_difference  394.0       8      2.9
# 2           points_difference|rolling_avg_goals_away  142.8       6      1.6
# 12          points_difference|team_acceleration_away   88.2       8      1.7
# 6        team_acceleration_home|team_aggression_home  104.0      12      1.9
# 15         team_acceleration_home|team_strength_home   81.5       8      1.3
# 10  goal_conversion_rate_away|team_acceleration_home   90.7      10      1.3
# 17         team_aggression_home|team_aggression_home   78.2       7      0.8
# 9        team_acceleration_away|team_aggression_away   95.4       9      0.6
# 19       away_last_team_possession|points_difference   76.4       6      0.4
#
#     Average wFScore  Average Gain  Expected Gain  Gain Rank  FScore Rank  \
# 1               0.3          29.0          116.2          2            3
# 0               0.4          49.3          200.4          1           17
# 2               0.3          23.8           62.3          3           38
# 12              0.2          11.0           26.5         13           18
# 6               0.2           8.7           11.8          7            2
# 15              0.2          10.2           13.6         16           19
# 10              0.1           9.1           14.1         11            6
# 17              0.1          11.2           10.0         18           29
# 9               0.1          10.6            5.0         10           10
# 19              0.1          12.7           12.7         20           39
#
#     wFScore Rank  Avg wFScore Rank  Avg Gain Rank  Expected Gain Rank  \
# 1              2                 8              2                   2
# 0              1                 1              1                   1
# 2              8                 9              3                   3
# 12             6                14             15                   4
# 6              5                21             69                  12
# 15            18                20             34                  10
# 10            15                27             61                   8
# 17            24                29             13                  18
# 9             33                53             25                  39
# 19            51                50              6                  11
#
#     Average Rank  Average Tree Index  Average Tree Depth
# 1            3.2                 2.0                 4.0
# 0            3.7                16.0                 2.5
# 2           10.7                 1.8                 5.2
# 12          11.7                13.5                 4.8
# 6           19.3                 3.8                 6.4
# 15          19.5                 6.9                 3.6
# 10          21.3                 6.8                 7.0
# 17          21.8                 2.6                 6.3
# 9           28.3                11.8                 5.7
# 19          29.5                 2.8                 5.3

# %%
(X_trn
 .assign(match_result=y_trn)
 .corr(method='spearman')
 .loc[:, ['points_difference', 'team_acceleration_home', 'rolling_avg_goals_away', 'team_acceleration_away', 'team_strength_home', 'rolling_avg_goals_home']]
 .style
 .background_gradient(cmap='RdBu', vmin=-1, vmax=1)
 .format('{:.2f}')
)
# Out:
# <style type="text/css">
# #T_72217_row0_col0, #T_72217_row17_col5, #T_72217_row20_col0 {
#   background-color: #b8d8e9;
#   color: #000000;
# }
# #T_72217_row0_col1, #T_72217_row2_col1, #T_72217_row5_col3, #T_72217_row6_col2, #T_72217_row7_col0, #T_72217_row23_col1, #T_72217_row29_col5 {
#   background-color: #e0ecf3;
#   color: #000000;
# }
# #T_72217_row0_col2, #T_72217_row4_col4, #T_72217_row6_col1, #T_72217_row9_col4, #T_72217_row9_col5, #T_72217_row11_col2, #T_72217_row14_col3, #T_72217_row15_col1, #T_72217_row18_col0, #T_72217_row18_col1, #T_72217_row19_col3, #T_72217_row19_col4, #T_72217_row20_col2, #T_72217_row21_col5, #T_72217_row22_col4, #T_72217_row23_col2, #T_72217_row23_col5, #T_72217_row24_col2, #T_72217_row24_col5, #T_72217_row25_col0, #T_72217_row25_col3, #T_72217_row27_col0, #T_72217_row28_col0 {
#   background-color: #f6f7f7;
#   color: #000000;
# }
# #T_72217_row0_col3, #T_72217_row13_col1, #T_72217_row25_col4 {
#   background-color: #f8f3f0;
#   color: #000000;
# }
# #T_72217_row0_col4, #T_72217_row9_col2 {
#   background-color: #e9f0f4;
#   color: #000000;
# }
# #T_72217_row0_col5 {
#   background-color: #d5e7f1;
#   color: #000000;
# }
# #T_72217_row1_col0 {
#   background-color: #f8bda1;
#   color: #000000;
# }
# #T_72217_row1_col1, #T_72217_row10_col1, #T_72217_row19_col5 {
#   background-color: #f8f1ed;
#   color: #000000;
# }
# #T_72217_row1_col2 {
#   background-color: #d2e6f0;
#   color: #000000;
# }
# #T_72217_row1_col3, #T_72217_row3_col1 {
#   background-color: #deebf2;
#   color: #000000;
# }
# #T_72217_row1_col4, #T_72217_row3_col2 {
#   background-color: #f0f4f6;
#   color: #000000;
# }
# #T_72217_row1_col5, #T_72217_row4_col2, #T_72217_row5_col5, #T_72217_row8_col3, #T_72217_row15_col4, #T_72217_row23_col0, #T_72217_row24_col0, #T_72217_row26_col0 {
#   background-color: #f7f6f6;
#   color: #000000;
# }
# #T_72217_row2_col0, #T_72217_row3_col0, #T_72217_row6_col3, #T_72217_row29_col1 {
#   background-color: #ddebf2;
#   color: #000000;
# }
# #T_72217_row2_col2, #T_72217_row4_col3, #T_72217_row6_col4, #T_72217_row7_col4, #T_72217_row10_col5, #T_72217_row25_col1, #T_72217_row25_col2 {
#   background-color: #f5f6f7;
#   color: #000000;
# }
# #T_72217_row2_col3, #T_72217_row5_col4, #T_72217_row12_col5, #T_72217_row24_col3, #T_72217_row25_col5 {
#   background-color: #f3f5f6;
#   color: #000000;
# }
# #T_72217_row2_col4, #T_72217_row10_col2, #T_72217_row11_col3, #T_72217_row22_col5 {
#   background-color: #f8f2ef;
#   color: #000000;
# }
# #T_72217_row2_col5 {
#   background-color: #59a1ca;
#   color: #f1f1f1;
# }
# #T_72217_row3_col3, #T_72217_row5_col1, #T_72217_row18_col2, #T_72217_row19_col1, #T_72217_row22_col0 {
#   background-color: #f7f5f4;
#   color: #000000;
# }
# #T_72217_row3_col4, #T_72217_row11_col5, #T_72217_row12_col4, #T_72217_row28_col4, #T_72217_row29_col4 {
#   background-color: #ecf2f5;
#   color: #000000;
# }
# #T_72217_row3_col5 {
#   background-color: #dbeaf2;
#   color: #000000;
# }
# #T_72217_row4_col0, #T_72217_row6_col0, #T_72217_row9_col0 {
#   background-color: #fae9df;
#   color: #000000;
# }
# #T_72217_row4_col1, #T_72217_row12_col0, #T_72217_row24_col4 {
#   background-color: #fae8de;
#   color: #000000;
# }
# #T_72217_row4_col5, #T_72217_row27_col3 {
#   background-color: #fbe4d6;
#   color: #000000;
# }
# #T_72217_row5_col0 {
#   background-color: #fce0d0;
#   color: #000000;
# }
# #T_72217_row5_col2 {
#   background-color: #529dc8;
#   color: #f1f1f1;
# }
# #T_72217_row6_col5, #T_72217_row26_col5 {
#   background-color: #eff3f5;
#   color: #000000;
# }
# #T_72217_row7_col1, #T_72217_row8_col2, #T_72217_row8_col5, #T_72217_row13_col5, #T_72217_row18_col3, #T_72217_row20_col4, #T_72217_row21_col4, #T_72217_row24_col1, #T_72217_row28_col2, #T_72217_row28_col5 {
#   background-color: #f2f5f6;
#   color: #000000;
# }
# #T_72217_row7_col2, #T_72217_row11_col1, #T_72217_row12_col3, #T_72217_row27_col1 {
#   background-color: #fbe6da;
#   color: #000000;
# }
# #T_72217_row7_col3, #T_72217_row16_col4, #T_72217_row29_col3 {
#   background-color: #faeae1;
#   color: #000000;
# }
# #T_72217_row7_col5, #T_72217_row14_col2, #T_72217_row15_col5, #T_72217_row20_col3, #T_72217_row21_col1, #T_72217_row22_col2, #T_72217_row23_col4 {
#   background-color: #f8f4f2;
#   color: #000000;
# }
# #T_72217_row8_col0, #T_72217_row17_col4, #T_72217_row27_col4 {
#   background-color: #eaf1f5;
#   color: #000000;
# }
# #T_72217_row8_col1, #T_72217_row9_col3, #T_72217_row14_col4 {
#   background-color: #fae7dc;
#   color: #000000;
# }
# #T_72217_row8_col4, #T_72217_row14_col1, #T_72217_row15_col3, #T_72217_row17_col0, #T_72217_row20_col5, #T_72217_row21_col2 {
#   background-color: #053061;
#   color: #f1f1f1;
# }
# #T_72217_row9_col1, #T_72217_row13_col2, #T_72217_row27_col5 {
#   background-color: #f9efe9;
#   color: #000000;
# }
# #T_72217_row10_col0, #T_72217_row23_col3 {
#   background-color: #e1edf3;
#   color: #000000;
# }
# #T_72217_row10_col3, #T_72217_row12_col2, #T_72217_row13_col3, #T_72217_row22_col1 {
#   background-color: #e7f0f4;
#   color: #000000;
# }
# #T_72217_row10_col4 {
#   background-color: #3480b9;
#   color: #f1f1f1;
# }
# #T_72217_row11_col0 {
#   background-color: #e6eff4;
#   color: #000000;
# }
# #T_72217_row11_col4, #T_72217_row16_col1 {
#   background-color: #337eb8;
#   color: #f1f1f1;
# }
# #T_72217_row12_col1 {
#   background-color: #f9ebe3;
#   color: #000000;
# }
# #T_72217_row13_col0 {
#   background-color: #dae9f2;
#   color: #000000;
# }
# #T_72217_row13_col4 {
#   background-color: #7bb6d6;
#   color: #000000;
# }
# #T_72217_row14_col0, #T_72217_row17_col1 {
#   background-color: #bddbea;
#   color: #000000;
# }
# #T_72217_row14_col5, #T_72217_row20_col1 {
#   background-color: #cfe4ef;
#   color: #000000;
# }
# #T_72217_row15_col0, #T_72217_row17_col3 {
#   background-color: #fbccb4;
#   color: #000000;
# }
# #T_72217_row15_col2, #T_72217_row21_col3 {
#   background-color: #c5dfec;
#   color: #000000;
# }
# #T_72217_row16_col0 {
#   background-color: #9dcbe1;
#   color: #000000;
# }
# #T_72217_row16_col2 {
#   background-color: #fcdecd;
#   color: #000000;
# }
# #T_72217_row16_col3 {
#   background-color: #c84440;
#   color: #f1f1f1;
# }
# #T_72217_row16_col5 {
#   background-color: #d8e9f1;
#   color: #000000;
# }
# #T_72217_row17_col2, #T_72217_row21_col0 {
#   background-color: #f9c2a7;
#   color: #000000;
# }
# #T_72217_row18_col4, #T_72217_row26_col3 {
#   background-color: #f9eee7;
#   color: #000000;
# }
# #T_72217_row18_col5 {
#   background-color: #b3d6e8;
#   color: #000000;
# }
# #T_72217_row19_col0, #T_72217_row28_col3 {
#   background-color: #f9f0eb;
#   color: #000000;
# }
# #T_72217_row19_col2 {
#   background-color: #a9d1e5;
#   color: #000000;
# }
# #T_72217_row22_col3 {
#   background-color: #e4eef4;
#   color: #000000;
# }
# #T_72217_row26_col1, #T_72217_row27_col2, #T_72217_row28_col1 {
#   background-color: #f9ede5;
#   color: #000000;
# }
# #T_72217_row26_col2, #T_72217_row26_col4 {
#   background-color: #edf2f5;
#   color: #000000;
# }
# #T_72217_row29_col0 {
#   background-color: #b6d7e8;
#   color: #000000;
# }
# #T_72217_row29_col2 {
#   background-color: #fbe5d8;
#   color: #000000;
# }
# </style>
# <table id="T_72217">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72217_level0_col0" class="col_heading level0 col0" >points_difference</th>
#       <th id="T_72217_level0_col1" class="col_heading level0 col1" >team_acceleration_home</th>
#       <th id="T_72217_level0_col2" class="col_heading level0 col2" >rolling_avg_goals_away</th>
#       <th id="T_72217_level0_col3" class="col_heading level0 col3" >team_acceleration_away</th>
#       <th id="T_72217_level0_col4" class="col_heading level0 col4" >team_strength_home</th>
#       <th id="T_72217_level0_col5" class="col_heading level0 col5" >rolling_avg_goals_home</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72217_level0_row0" class="row_heading level0 row0" >points_home</th>
#       <td id="T_72217_row0_col0" class="data row0 col0" >0.28</td>
#       <td id="T_72217_row0_col1" class="data row0 col1" >0.12</td>
#       <td id="T_72217_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_72217_row0_col3" class="data row0 col3" >-0.03</td>
#       <td id="T_72217_row0_col4" class="data row0 col4" >0.07</td>
#       <td id="T_72217_row0_col5" class="data row0 col5" >0.18</td>
#     </tr>
#     <tr>
#       <th id="T_72217_level0_row1" class="row_hea
